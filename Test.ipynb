# %%
import pandas as pd
music = pd.read_csv("charts.csv")

# %%
music.shape
# Out:
# (26173514, 9)

# %%
# Out:
#                                             title  rank        date  \
# 3234                                      Starboy     1  2017-01-01
# 3235                                       Closer     2  2017-01-01
# 3236                              Let Me Love You     3  2017-01-01
# 3237      Rockabye (feat. Sean Paul & Anne-Marie)     4  2017-01-01
# 3238                                    One Dance     5  2017-01-01
# ...                                           ...   ...         ...
# 25275674                                 Stir Fry     2  2018-01-31
# 25275675           Finesse - Remix; feat. Cardi B     3  2018-01-31
# 25275676                                 rockstar     4  2018-01-31
# 25275677                               The Middle     5  2018-01-31
# 25275678                                   Narcos     6  2018-01-31
#
#                             artist  \
# 3234         The Weeknd, Daft Punk
# 3235      The Chainsmokers, Halsey
# 3236       DJ Snake, Justin Bieber
# ...
